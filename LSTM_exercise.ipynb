# %%
import torch
import torch.nn as nn
from torch.nn import Parameter
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Making an LSTM from scratch
#
# ### To start you will be filling in the blanks to create your own LSTM.
# ### Here are the equations you will need:
#
# $f_t=σ(W_{fx}\cdot x_t+W_{fh}\cdot h_t+b_f)$
#
# $i_t=σ(W_{ix}\cdot x_t+W_{ih}\cdot h_t+b_i)$
#
# $\tilde c_t=tanh(W_{cx}\cdot x_t+W_{ch}\cdot h_t+b_c)$
#
# $o_t=σ(W_{ox}\cdot x_t+W_{oh}\cdot h_t+b_o)$
#
# $C_t=f_t∗C_t+i_t∗\tilde c_t$
#
# $h_t=o_t∗tanh(C_t)$
#
# ### and here are the matrix and vector sizes you will need to know:
#
# $H$ = size of hidden state, $I$ = size of input features
#
# $f_t,i_t,\tilde c_t,o_t,h_t,C_t = H \times 1$
#
# $x_t = I \times 1$
#
# $W_{fx},W_{ix},W_{cx},W_{ox} = H \times I$
#
# $W_{fh},W_{ih},W_{ch},W_{oh} = H \times H$
#
# $b_{f},b_{i},b_{c},b_{o} = H \times 1$

# %%
class LSTM(nn.Module):
    def __init__(self,inputsz,hiddensz):
        super().__init__()
        self.inputsz=inputsz
        self.hiddensz=hiddensz
        
        #input gate
        self.Wix =  Parameter(torch.zeros(hiddensz, inputsz))
        self.Wih = Parameter(torch.zeros(hiddensz, hiddensz))
        self.bi = Parameter(torch.zeros(hiddensz, 1))
        
        
        #forget gate
        self.Wfx =  Parameter(torch.zeros(hiddensz, inputsz))
        self.Wfh = Parameter(torch.zeros(hiddensz, hiddensz))
        self.bf = Parameter(torch.zeros(hiddensz, 1))                   

        #c gate
        self.Wcx =  Parameter(torch.zeros(hiddensz, inputsz))
        self.Wch = Parameter(torch.zeros(hiddensz, hiddensz))
        self.bc = Parameter(torch.zeros(hiddensz, 1))
                             
        #output gate
        self.Wox =  Parameter(torch.zeros(hiddensz, inputsz))
        self.Woh = Parameter(torch.zeros(hiddensz, hiddensz))
        self.bo = Parameter(torch.zeros(hiddensz, 1))
        
        print(self.Wix.size())
        
        
        #paramter initialization
        for p in self.parameters():  
            if p.data.ndimension()>=2:
                nn.init.xavier_uniform_(p.data)
            else:
                nn.init.zeros_(p.data)
                
    def forward(self,x,initstates=None):
        m = len(x)
        hidden_seq = []
        if initstates is None:
            ht,ct = torch.zeros((self.hiddensz, 1)), torch.zeros((self.hiddensz, 1))
        else:
            ht,ct = initstates
        for t in range(m):
            xt = x[t,:]
            it = torch.sigmoid(self.Wix @ xt + self.Wih @ ht + self.bi)
            ft = torch.sigmoid(self.Wfx @ xt + self.Wfh @ ht + self.bf)
            gt = torch.tanh(self.Wcx @ xt + self.Wch @ ht + self.bc)
            ot = torch.sigmoid(self.Wox @ xt + self.Woh @ ht + self.bo)
            ct = ft * ct + it * gt
            ht = ot * torch.tanh(ct)
            hidden_seq.append(ht.unsqueeze(0))
        hidden_seq = torch.cat(hidden_seq,dim=0)
        return hidden_seq, (ht,ct)

LSTM(2,3)
# Out:
# torch.Size([3, 2])
# LSTM()

# %%
class customDataset(Dataset):

    def __init__(self, x, transform=None):
        self.data = x
        

    def __len__(self):
        return len(self.data)

    def __getitem__(self, i):
        return self.data[i]

# %% [markdown]
# # Addition
#
# ### First we are going to be teaching the LSTM to do addition.

# %%
def addData(size):
    size = np.random.choice(range(size,size+int(size/10)))
    inputs = torch.Tensor([[np.random.uniform(-.5,.5),0] for i in range(size)])
    choice1 = np.random.choice(range(1,10))
    choice2 = list(range(1,int(size/2)))
    choice2.remove(choice1)
    choice2 = np.random.choice(choice2)
    inputs[choice1,1]=1
    inputs[choice2,1]=1
    label = inputs[:,0][inputs[:,1]==1].sum()
    return inputs,label

# %% [markdown]
# ### Here's a look at the data. The goal is to learn to add the numbers in the left row that have a corresponding 1 in the right row while ignoring the rest.

# %%
addData(20)
# Out:
# (tensor([[-0.2392,  0.0000],
#          [ 0.0478,  0.0000],
#          [ 0.2495,  0.0000],
#          [-0.3961,  1.0000],
#          [-0.2147,  0.0000],
#          [ 0.1769,  1.0000],
#          [ 0.4549,  0.0000],
#          [-0.0778,  0.0000],
#          [-0.0269,  0.0000],
#          [-0.1758,  0.0000],
#          [-0.4018,  0.0000],
#          [-0.0819,  0.0000],
#          [ 0.2518,  0.0000],
#          [-0.2477,  0.0000],
#          [-0.3428,  0.0000],
#          [-0.4403,  0.0000],
#          [-0.0662,  0.0000],
#          [-0.3624,  0.0000],
#          [ 0.4418,  0.0000],
#          [-0.0782,  0.0000],
#          [ 0.3216,  0.0000]]), tensor(-0.2192))

# %%
size = 20

train = customDataset([addData(size) for i in range(20)])
train_loader = DataLoader(train,batch_size = 1, shuffle = False)

val = customDataset([addData(size) for i in range(20)])
val_loader = DataLoader(val,batch_size = 1, shuffle = False)

test = customDataset([addData(size) for i in range(100)])
test_loader = DataLoader(test,batch_size = 1, shuffle = False)

# %%
featsz, hiddensz = 2, 1
model = LSTM(featsz, hiddensz)
# Define hyperparameters
n_epochs = 100
lr=.02

# Define Loss, Optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr,weight_decay = .0001)
# Out:
# torch.Size([1, 2])

# %%
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz),torch.zeros(hiddensz)
    losslist = []
    for d,t in train_loader:
        optimizer.zero_grad()
        output, hidden = model(d.squeeze(0),hidden)
        loss = criterion(output.sum(), t)
        
        loss.backward(retain_graph=True)
        losslist.append(loss.item())
        optimizer.step()
    model.eval()
    validationlist = []
    for d,t in val_loader:
        output,hidden = model(d.squeeze(0))
        loss = criterion(output.sum(), t)
        validationlist.append(loss.item())
    currval = np.mean(validationlist)
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4f},val Loss: {:.4f}".format(np.mean(losslist),currval))
# Out:
# /home/aaron/anaconda3/envs/ml/lib/python3.7/site-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epo
# Epoch: 58/100............. training: 0.0236,val Loss: 0.0342
# Epoch: 59/100............. training: 0.0228,val Loss: 0.0334
# Epoch: 60/100............. training: 0.0220,val Loss: 0.0325
# Epoch: 61/100............. training: 0.0213,val Loss: 0.0316
# Epoch: 62/100............. training: 0.0206,val Loss: 0.0307
# Epoch: 63/100............. training: 0.0199,val Loss: 0.0299
# Epoch: 64/100............. training: 0.0193,val Loss: 0.0290
# Epoch: 65/100............. training: 0.0187,val Loss: 0.0282
# Epoch: 66/100............. training: 0.0181,val Loss: 0.0274
# Epoch: 67/100............. training: 0.0175,val Loss: 0.0266
# Epoch: 68/100............. training: 0.0170,val Loss: 0.0258
# Epoch: 69/100............. training: 0.0166,val Loss: 0.0251
# Epoch: 70/100............. training: 0.0161,val Loss: 0.0245
# Epoch: 71/100............. training: 0.0157,val Loss: 0.0239
# Epoch: 72/100............. training: 0.0153,val Loss: 0.0233
# Epoch: 73/100............. training: 0.0150,val Loss: 0.0228
# Epoch: 74/100............. training: 0.0146,val Loss: 0.0223
# Epoch: 75/100............. training: 0.0143,val Loss: 0.0218
# Epoch: 76/100............. training: 0.0140,val Loss: 0.0214
# Epoch: 77/100............. training: 0.0138,val Loss: 0.0211
# Epoch: 78/100............. training: 0.0136,val Loss: 0.0208
# Epoch: 79/100............. training: 0.0133,val Loss: 0.0205
# Epoch: 80/100............. training: 0.0132,val Loss: 0.0202
# Epoch: 81/100............. training: 0.0130,val Loss: 0.0200
# Epoch: 82/100............. training: 0.0128,val Loss: 0.0198
# Epoch: 83/100............. training: 0.0127,val Loss: 0.0197
# Epoch: 84/100............. training: 0.0126,val Loss: 0.0196
# Epoch: 85/100............. training: 0.0125,val Loss: 0.0195
# Epoch: 86/100............. training: 0.0124,val Loss: 0.0194
# Epoch: 87/100............. training: 0.0123,val Loss: 0.0193
# Epoch: 88/100............. training: 0.0122,val Loss: 0.0193
# Epoch: 89/100............. training: 0.0122,val Loss: 0.0193
# Epoch: 90/100............. training: 0.0121,val Loss: 0.0193
# Epoch: 91/100............. training: 0.0121,val Loss: 0.0194
# Epoch: 92/100............. training: 0.0120,val Loss: 0.0194
# Epoch: 93/100............. training: 0.0120,val Loss: 0.0195
# Epoch: 94/100............. training: 0.0120,val Loss: 0.0195
# Epoch: 95/100............. training: 0.0120,val Loss: 0.0196
# Epoch: 96/100............. training: 0.0119,val Loss: 0.0197
# Epoch: 97/100............. training: 0.0119,val Loss: 0.0198
# Epoch: 98/100............. training: 0.0119,val Loss: 0.0199
# Epoch: 99/100............. training: 0.0119,val Loss: 0.0201
# Epoch: 100/100............. training: 0.0119,val Loss: 0.0202

# %%
model.eval()
predictions = []
labels = []
for d,t in test_loader:
    output,hidden = model(d.squeeze(0))
    predictions.append(output.sum())
    labels.append(t)
plt.figure(figsize=(15,12))
plt.plot(predictions,'r-')
plt.plot(labels,'b-')

# %% [markdown]
# # Multiplication

# %% [markdown]
# ### Now we'll be trying to learn to multiply. The goal is essentially the same except instead of adding the two numbers we multiply them.

# %%
def multData(size):
    size = np.random.choice(range(size,size+int(size/10)))
    inputs = torch.Tensor([[np.random.uniform(0,1),0] for i in range(size)])
    choice1 = np.random.choice(range(1,10))
    choice2 = list(range(1,int(size/2)))
    choice2.remove(choice1)
    choice2 = np.random.choice(choice2)
    inputs[choice1,1]=1
    inputs[choice2,1]=1
    label = inputs[:,0][inputs[:,1]==1].prod()
    return inputs,label

# %%
size = 20
train = customDataset([multData(size) for i in range(20)])
train_loader = DataLoader(train,batch_size = 1, shuffle = False)

val = customDataset([multData(size) for i in range(20)])
val_loader = DataLoader(val,batch_size = 1, shuffle = False)


test = customDataset([multData(size) for i in range(40)])
test_loader = DataLoader(test,batch_size = 1, shuffle = False)

# %%
featsz, hiddensz = 2, 1
model = LSTM(featsz, hiddensz)
# Define hyperparameters
n_epochs = 1000
lr=.02

# Define Loss, Optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr,weight_decay = .0001)
# Out:
# torch.Size([1, 2])

# %%
model.train()
minimum = 100
n_epochs = 100
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz),torch.zeros(hiddensz)
    
    losslist = []
    for d,t in train_loader:
        optimizer.zero_grad()
        output, hidden = model(d.squeeze(0),hidden)
        loss = criterion(hidden[0], t)
        loss.backward(retain_graph=True)
        losslist.append(loss.item())
        optimizer.step()
    model.eval()
    validationlist = []
    for d,t in val_loader:
        output,hidden = model(d.squeeze(0))
        predictions.append(hidden[0].item())
        labels.append(t.item())
        loss = criterion(hidden[0], t)
        validationlist.append(loss.item())
    currval = np.mean(validationlist)
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4f},val Loss: {:.4f}".format(np.mean(losslist),currval))
# Out:
# /home/aaron/anaconda3/envs/ml/lib/python3.7/site-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch: 1/100............. training: 0.0710,val Loss: 0.0417
# Epoch: 2/100............. training: 0.0624,val Loss: 0.0416
# Epoch: 3/100............. training: 0.0632,val Loss: 0.0425
# Epoch: 4/100............. training: 0.0616,val Loss: 0.0432
# Epoch: 5/100............. training: 0.0605,val Loss: 0.0441
# Epoch: 6/100............. training: 0.0598,val Loss: 0.0450
# Epoch: 7/100............. training: 0.0591,val Loss: 0.0458
# Epoch: 8/100............. training: 0.0585,val Loss: 0.0467
# Epoch: 9/100............. training: 0.0579,val Loss: 0.0475
# Epoch: 10/100............. training: 0.0574,val Loss: 0.0483
# Epoch: 11/100............. training: 0.0570,val Loss: 0.0490
# Epoch: 12/100............. training: 0.0566,val Loss: 0.0498
# Epoch: 13/100............. training: 0.0562,val Loss: 0.0505
# Epoch: 14/100............. training: 0.0558,val Loss: 0.0513
# Epoch: 15/100............. training: 0.0554,val Loss: 0.0520
# Epoch: 16/100............. training: 0.0551,val Loss: 0.0527
# Epoch: 17/100............. training: 0.0548,val Loss: 0.0534
# Epoch: 18/100............. training: 0.0545,val Loss: 0.0540
# Epoch: 19/100............. training: 0.0543,val Loss: 0.0547
# Epoch: 20/100............. training: 0.0540,val Loss: 0.0553
# Epoch: 21/100............. training: 0.0538,val Loss: 0.0560
# Epoch: 22/100............. training: 0.0535,val Loss: 0.0566
# Epoch: 74/100............. training: 0.0485,val Loss: 0.0837
# Epoch: 75/100............. training: 0.0485,val Loss: 0.0844
# Epoch: 76/100............. training: 0.0484,val Loss: 0.0850
# Epoch: 77/100............. training: 0.0484,val Loss: 0.0857
# Epoch: 78/100............. training: 0.0483,val Loss: 0.0863
# Epoch: 79/100............. training: 0.0483,val Loss: 0.0869
# Epoch: 80/100............. training: 0.0482,val Loss: 0.0875
# Epoch: 81/100............. training: 0.0481,val Loss: 0.0881
# Epoch: 82/100............. training: 0.0481,val Loss: 0.0887
# Epoch: 83/100............. training: 0.0480,val Loss: 0.0892
# Epoch: 84/100............. training: 0.0480,val Loss: 0.0898
# Epoch: 85/100............. training: 0.0479,val Loss: 0.0903
# Epoch: 86/100............. training: 0.0479,val Loss: 0.0908
# Epoch: 87/100............. training: 0.0478,val Loss: 0.0913
# Epoch: 88/100............. training: 0.0478,val Loss: 0.0917
# Epoch: 89/100............. training: 0.0478,val Loss: 0.0922
# Epoch: 90/100............. training: 0.0477,val Loss: 0.0926
# Epoch: 91/100............. training: 0.0477,val Loss: 0.0930
# Epoch: 92/100............. training: 0.0476,val Loss: 0.0934
# Epoch: 93/100............. training: 0.0476,val Loss: 0.0938
# Epoch: 94/100............. training: 0.0475,val Loss: 0.0942
# Epoch: 95/100............. training: 0.0475,val Loss: 0.0946
# Epoch: 96/100............. training: 0.0474,val Loss: 0.0949
# Epoch: 97/100............. training: 0.0474,val Loss: 0.0952
# Epoch: 98/100............. training: 0.0474,val Loss: 0.0955
# Epoch: 99/100............. training: 0.0473,val Loss: 0.0958
# Epoch: 100/100............. training: 0.0473,val Loss: 0.0961

# %%
model.eval()
predictions = []
labels = []
for d,t in test_loader:
    output,hidden = model(d.squeeze(0))
    predictions.append(hidden[0])
    labels.append(t)
plt.figure(figsize=(15,12))
plt.plot(predictions,'r-')
plt.plot(labels,'b-')

# %% [markdown]
# # Questions
#
# 1. Why is addition easy for the LSTM to learn?
#
#
# 2. Why is multiplication harder for the LSTM to learn?
#
# I would guess that multiplication is simply a more complex algorithm.

# %% [markdown]
# # Language Model
#
# ### Here we'll be teaching a model to produce shakespeare. It's a slow a task so we'll be using a more optimized and slightly changed LSTM to do it. The weight matrices have been stacked to reduce the number of matrix multiplications performed and the output now has its own weight matrix. You just need to fill in the function with the correct part of the gates matrix.

# %%
class betterLSTM(nn.Module):
    def __init__(self,inputsz,hiddensz):
        super().__init__()
        self.inputsz=inputsz
        self.hiddensz=hiddensz
        
        #input gate
        self.Wx =  Parameter(torch.Tensor(hiddensz*4,inputsz))
        self.Wh = Parameter(torch.Tensor(hiddensz*4,hiddensz))
        self.Wy = Parameter(torch.Tensor(inputsz,hiddensz))
        self.by = Parameter(torch.Tensor(inputsz,1))
        self.b = Parameter(torch.Tensor(hiddensz*4,1))
        #paramter initialization
        for p in self.parameters():
            if p.data.ndimension()>=2:
                nn.init.xavier_uniform_(p.data)
            else:
                nn.init.zeros_(p.data)
                
    def forward(self,x,initstates=None):
        m = len(x)
        hidden_seq = []
        if initstates is None:
            ht,ct = torch.zeros(self.hiddensz,1),torch.zeros(self.hiddensz,1)
        else:
            ht,ct = initstates
        xt = x
        gates = self.Wx@xt+self.Wh@ht+self.b
        it = torch.sigmoid(gates[:hiddensz][:])
        ft = torch.sigmoid(gates[hiddensz : 2*hiddensz][:])
        gt = torch.tanh(gates[2*hiddensz : 3*hiddensz][:])
        ot = torch.sigmoid(gates[3*hiddensz : 4*hiddensz][:])
        ct = ft*ct+it*gt
        ht = ot*torch.tanh(ct)
        output = self.Wy@ht+self.by
        return output, (ht,ct)

# %% [markdown]
# ### Here we load the data and transform it into one-hot vectors.

# %%
file = open('clean_shakespeare.txt','r')
text = file.read()
letters = 'abcdefghijklmnopqrstuvwxyz '
# one hot encode characters
char_dict = {}
for i,char in enumerate(letters):
    vec = torch.zeros(27)
    vec[i] += 1
    char_dict[char] = vec

total_data = 40000

D = []
for i in range(total_data):
    x = text[i]
    y = text[i+1]
    D.append((char_dict[x],char_dict[y]))


featsz, hiddensz = 27, 64
model = betterLSTM(featsz, hiddensz)

# %% [markdown]
# ### This function generates text with our model. You can try different seeds to see what you get. "rand" influences randomness in the text generation and "size" determines how many characters will be produced.

# %%
seed = 'to be or not to be that is the question'
def text_gen(model,seed,rand=5,h_size=32,size=100):
    n = len(seed)
    one_hot = torch.zeros(n,27)
    for i in range(n):
        one_hot[i] = char_dict[seed[i]]
    hidden = torch.zeros(hiddensz,1),torch.zeros(hiddensz,1)
    last_char = ''
    for vec in one_hot:
        y_hat,hidden = model(vec.unsqueeze(1),hidden)
        out = y_hat.permute((1,0))
    char = letters[torch.argmax(out)]
    seed += char
    for i in range(size):
        last_char = char
        y_hat,hidden = model(char_dict[last_char].unsqueeze(1),hidden)
        out = y_hat.permute((1,0))
        if last_char == ' ':
            best = torch.argsort(out)
            best = best[-rand:]
            char = np.random.choice(best.squeeze(0))
            char = letters[char]
        else:
            char = torch.argmax(out)
            char = letters[char]
        seed += char
    return seed

# %%
train = customDataset(D)
train_loader = DataLoader(train,batch_size = 1, shuffle = False)
lr = .001
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ### We truncated the back propogation to speed things up. You can try different values of truncation to see how it performs.
#
# ### DB COMMENT: Is this really truncation as we usually understand it?  It looks like we're just ignoring most of the training data via this "truncation term"...

# %%
n_epochs = 30
truncate = 32
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz,1),torch.zeros(hiddensz,1)
    losslist = []
    i = 1
    loss = 0
    for d,t in train_loader:
        if i%truncate==0:
            loss.backward(retain_graph=True)
            optimizer.step()
            optimizer.zero_grad()
            loss = 0
            hidden = (hidden[0].data,hidden[1].data)
        output, hidden = model(d.permute((1,0)),hidden)
        loss += criterion(output.permute((1,0)),t.argmax(dim=1))
        losslist.append(loss.item())
        i += 1
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4f}".format(np.mean(losslist)))
    model.eval()
    print(text_gen(model,seed,size=1000,rand=10,h_size=hiddensz))

# %% [markdown]
# # Questions
#
# 1. What is the purpose of truncated back-prop?
#
#
# 2. Say we truncate back-propagation at 50 time steps. Can the cell state carry information from more
#     than 50 time steps back?
